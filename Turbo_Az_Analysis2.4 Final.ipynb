# %% [markdown]
# <a href="https://colab.research.google.com/github/hemidovaqil/turboaz-cars-analysis/blob/main/Turbo_Az_Analysis2.4%20Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Checking Assumptions
#
# Before applying parametric tests, the normality of the distribution and the equality of variances were checked.

# %% [markdown]
# ## Business Interpretation of Results
#
# The analysis revealed statistically significant differences in car prices across the groups. This indicates that the selected factor (e.g., fuel type) influences the vehicle's cost.
#
# From a practical standpoint, this allows the factor to be taken into account during pricing, market analysis, and decision-making. For instance, sellers can adjust prices based on vehicle characteristics, while buyers can make more informed decisions regarding offers.
#
# Thus, the analysis results can be used to enhance the accuracy of valuation and improve the quality of decision-making.
