# %% [markdown]
# <a href="https://colab.research.google.com/github/hemidovaqil/turboaz-cars-analysis/blob/main/Turboaz_cars_analysis2.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Statistical Analysis (t-test and confidence interval)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

sns.set(style="whitegrid")

# %%
df = pd.read_csv("cars.csv")
df.head()
# Out:
#                                    id_x                        car_rel_url_x  \
# 0  3c234145-d57a-4ad6-9448-d43810fc3392           /autos/8748840-hyundai-i30
# 1  c74ea36f-6be1-4de4-926d-e117197dcf00  /autos/8475807-lada-vaz-niva-travel
# 2  9cefceb0-024d-4581-a869-a3c2c68a9f95   /autos/8739686-toyota-land-cruiser
# 3  459cc337-fb63-48de-9694-41554923d311       /autos/8712597-hyundai-elantra
# 4  6c5ee8d8-1c6f-4fad-a694-957a4c43c25d          /autos/8674773-toyota-prius
#
#                  datetime_scrape                    name  price_x currency_x  \
# 0  2024-09-13 20:32:19.751157+00             Hyundai i30  15000.0        AZN
# 1  2024-09-13 20:32:19.751157+00  LADA (VAZ) Niva Travel  23700.0        AZN
# 2  2024-09-13 20:32:19.751157+00     Toyota Land Cruiser  35600.0          $
# 3  2024-09-13 20:32:19.751157+00         Hyundai Elantra  26700.0        AZN
# 4  2024-09-13 20:32:19.751157+00            Toyota Prius  10500.0        AZN
#
# ...

# %%
df.info()
df.describe()

# Проверка пропусков
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12075 entries, 0 to 12074
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_x                      12075 non-null  object
#  1   car_rel_url_x             12075 non-null  object
#  2   datetime_scrape           12075 non-null  object
#  3   name                      12075 non-null  object
#  4   price_x                   12075 non-null  float64
#  5   currency_x                12075 non-null  object
#  6   datetime_product          12075 non-null  object
#  7   city                      12075 non-null  object
#  8   day                       12075 non-null  object
#  9   hour                      12075 non-null  object
#  10  attributes                12075 non-null  object
#  11  production_year           12075 non-null  int64
#  12  engine_displacement_num   12075 non-null  float64
# ...

# %%
print(df.columns)
# Out:
# Index(['id_x', 'car_rel_url_x', 'datetime_scrape', 'name', 'price_x',
#        'currency_x', 'datetime_product', 'city', 'day', 'hour', 'attributes',
#        'production_year', 'engine_displacement_num',
#        'engine_displacement_unit', 'kilometrage_num', 'kilometrage_unit',
#        'barter', 'loan', 'salon', 'spare_parts', 'vip', 'featured', 'img_url',
#        'id_y', 'cars_id', 'car_rel_url_y', 'datetime', 'description',
#        'price_y', 'currency_y', 'owner_name', 'shop_name', 'phone', 'updated',
#        'views', 'vin', 'car_details_id_x', 'Ban növü', 'Buraxılış ili',
#        'Hansı bazar üçün yığılıb', 'Marka', 'Model', 'Mühərrik', 'Qəzalı',
#        'Rəng', 'Sahiblər', 'Sürətlər qutusu', 'Vəziyyəti', 'Yeni',
#        'Yerlərin sayı', 'Yürüş', 'Ötürücü', 'Şəhər', 'car_details_id_y',
#        'car_rel_url', 'extra_info'],
#       dtype='object')

# %% [markdown]
# The test results show a statistically significant difference between the groups (p-value < 0.05).
# The confidence interval does not include zero, confirming the presence of an effect.
